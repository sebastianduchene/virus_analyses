# %%
import os, sys, re
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
res_aa = pd.read_csv('gc_empirical_aa_results_MA.csv', index_col=0)

# %%
pub_table_aa = res_aa.transpose()
pub_table_aa.to_csv('empirical_aa_pub.csv')
pub_table_aa
# Out:
#                      Heinze     Moureau  Pettersson
# JTT.P                     0           0           0
# JTTG.P                    0           0           0
# LG.P                      0           0           0
# LGG.P                     0           0           0
# MA.P                      0           0           0
# MA.Model     Poisson (0.99)  WAG (0.96)  WAG (0.97)
# DP.P                   0.02           0           0
# JTT.TL                3.037      12.051      14.313
# JTTG.TL               3.798      14.948      19.354
# LG.TL                 3.098      12.205      14.536
# LGG.TL                3.976      15.973      20.892
# MA.TL                  3.74       14.94       19.57
# DP.TL                  4.41       17.98       23.47
# Pass_seq_aa       0.9824561   0.8686869    0.902439

# %%
res_nt = pd.read_csv('gc_empirical_nt_results.csv', index_col = 0)
pub_table_nt = res_nt.transpose()
pub_table_nt.to_csv('empirical_nt_pub.csv')

# %%
pub_table_nt
# Out:
#                Heinze    Moureau  Pettersson
# JC.P         0.000000   0.004000    0.000000
# GTR.P        0.000000   0.000000    0.000000
# GTRG.P       0.000000   0.000000    0.000000
# JC.TL        4.338000  17.265000   18.694000
# GTR.TL       4.495000  15.898000   17.070000
# GTRG.TL      9.864000  30.825000   33.296000
# Pass_seq_nt  0.929825   0.232323    0.109756
